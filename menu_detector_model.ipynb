# %% [markdown]
# <a href="https://colab.research.google.com/github/jarvis-control/computer_vision/blob/main/menu_detector_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Menu Detector!')
# Out:
# Menu Detector!

# %%
# ------------------------
# Import Libraries
# ------------------------

from google.colab import drive
import torchvision.transforms as transforms
from PIL import Image, UnidentifiedImageError
from torch.utils.data import Dataset
import os
import numpy as np

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define Dataset Path

DATASET_PATH = '/content/drive/MyDrive/food101_dataset'
print('Dataset_path:', DATASET_PATH)


CUSTOM_CLASS_MAPPING = {
    "hamburger": "hamburger",
    "hot_dog": "hot_dog",
    "chocolate_cake": "dessert",   # label grouping | class consolidation
    "cheesecake": "dessert",       # label grouping | class consolidation
    "kebab": "kebab",
    "pilaf": "pilaf"
}

CLASSES = ['hamburger', 'hot_dog', 'dessert', 'kebab', 'pilaf']
CLASS_TO_IDX = {cls: i for i, cls in enumerate(CLASSES)}
NUM_CLASSES = len(CLASSES)

print(NUM_CLASSES)
print(CLASS_TO_IDX)

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
# Out:
# Dataset_path: /content/drive/MyDrive/food101_dataset
# 5
# {'hamburger': 0, 'hot_dog': 1, 'dessert': 2, 'kebab': 3, 'pilaf': 4}

# %%
# ------------------------
# Custom Dataset Class
# ------------------------

class FoodDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        print('images_length', len(self.images))
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        print('image_path', img_path)
        label = self.labels[idx]
        print('label', label)

        try:
            image = Image.open(img_path).convert('RGB')  # 3 Channel
        except (UnidentifiedImageError, OSError):
            print(f"Skipping broken image: {img_path}")
            return self.__getitem__((idx + 1) % len(self.images))

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
# ------------------------
# Gather and Split Data
# ------------------------

all_images = []

for original_class, mapped_class in CUSTOM_CLASS_MAPPING.items():
    class_path = os.path.join(DATASET_PATH, original_class)  # /content/drive/MyDrive/food101_dataset/hamburger
    print('class_path:', class_path)

    if not os.path.exists(class_path):
        print(f"Warning: {class_path} not found")
        continue

    for img in os.listdir(class_path):
        if img.endswith(('.jpg', '.jpeg', '.png')):  # .txt, .docx
            full_path = os.path.join(class_path, img)  # /content/drive/MyDrive/food101_dataset/hamburger/100057.jpg
            all_images.append((full_path, CLASS_TO_IDX[mapped_class]))

np.random.shuffle(all_images)

split = int(0.8 * len(all_images))
train_data = all_images[:split]  # 1000 | 800 train_data | 200 val_data
val_data = all_images[split:]

train_images, train_labels = zip(*train_data)
val_images, val_labels = zip(*val_data)

print('all_images:', all_images)

dataset = FoodDataset(train_images, train_labels)

print(len(dataset))

img, lbl = dataset[0]
# Out:
# class_path: /content/drive/MyDrive/food101_dataset/hamburger
# Warning: /content/drive/MyDrive/food101_dataset/hamburger not found
# class_path: /content/drive/MyDrive/food101_dataset/hot_dog
# class_path: /content/drive/MyDrive/food101_dataset/chocolate_cake
# class_path: /content/drive/MyDrive/food101_dataset/cheesecake
# class_path: /content/drive/MyDrive/food101_dataset/kebab
# class_path: /content/drive/MyDrive/food101_dataset/pilaf
# all_images: [('/content/drive/MyDrive/food101_dataset/chocolate_cake/3123414.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/612440.jpg', 1), ('/content/drive/MyDrive/food101_dataset/cheesecake/1975932.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/1841310.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1432067.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3118911.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/2752900.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2185089.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/295007.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/1694288.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1178892.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2870509.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/1282523.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1855652.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2398993.jpg', 2), ('/content/drive/MyDrive/food101_dataset/kebab/Image_34.jpg', 3), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/702171.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/54951.jpg', 2), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_72.jpg', 4), ('/content/drive/MyDrive/food101_dataset/hot_dog/489624.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3686868.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/210131.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/679424.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2302760.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/251994.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2940330.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3243885.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/343270.jpg', 1), ('/content/drive/MyDrive/food101_dataset/hot_dog/756061.jpg', 1), ('/content/drive/MyDrive/food101_dataset/hot_dog/133015.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1122368.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/1387859.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/87840.jpg', 1), ('/content/drive/MyDrive/food101_dataset/kebab/Image_24.jpg', 3), ('/content/drive/MyDrive/food101_dataset/cheesecake/3844925.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/1751518.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/576933.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1651632.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2056176.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/70867.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2964054.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/1600182.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2963302.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/840832.jpg', 1), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2661791.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/3130983.jpg', 2), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_63.jpg', 4), ('/content/drive/MyDrive/food101_dataset/kebab/Image_26.jpg', 3), ('/content/drive/MyDrive/food101_dataset/hot_dog/3736382.jpg', 1), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_62.jpg', 4), ('/content/drive/MyDrive/food101_dataset/cheesecake/3780311.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/1583520.jpg', 2), ('/content/drive/MyDrive/food101_dataset/kebab/Image_33.jpg', 3), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3104030.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1216475.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/1800646.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hot_dog/19 ...
# images_length 2526
# 2526
# image_path /content/drive/MyDrive/food101_dataset/chocolate_cake/3123414.jpg
# label 2
