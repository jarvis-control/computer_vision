# %% [markdown]
# <a href="https://colab.research.google.com/github/jarvis-control/computer_vision/blob/main/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download("pilaf rice dish",
                    limit=100,
                    output_dir="/content/pilaf_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )

# %%
# !rm -rf /content/pilaf_images/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, shutil

source_dir = '/content/pilaf_images/pilaf rice dish'
target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)

# %%
downloader.download("shashlik uzbek dish",
                    limit=100,
                    output_dir='/content/kebab_images',
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60)

# %%
# !rm -rf /content/kebab_images/

# %%
import os, shutil

source_dir = '/content/pilaf_images/shashlik uzbek dish'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)
