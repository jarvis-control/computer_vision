# %% [markdown]
# <a href="https://colab.research.google.com/github/jarvis-control/computer_vision/blob/main/cv_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/cat_image.jpg")

cv2_imshow(image)

# %%
print("SHAPE:", image.shape)
# 2848 => height
# 4272 => width
# 3    => color channels (BGR) => Blue, Green, Red

print("HEIGHT:", image.shape[0])
print("WIDTH:", image.shape[1])
print("CHANNELS:", image.shape[2])

# %%
(b, g, r) = image[100, 50]
print("Blue:", b, "Green:", g, "Red:", r)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)

# %%
resized = cv2.resize(gray,(350, 300))
cv2_imshow(resized)

# %%
cropped = gray[100:300, 150:350]
cv2_imshow(cropped)

# %%
rotated = cv2.rotate(gray, cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(rotated)

# %%
flipped = cv2.flip(gray, 1)
cv2_imshow(flipped)

# %%
cv2.imwrite("cropped_cat.jpg", cropped)

# %%
cropped_cat = cv2.imread("/content/cropped_cat.jpg")

cv2_imshow(cropped_cat)
